# %% [markdown]
# # Install Python Dependencies from requirements.txt
# Use a shell command to install all required Python packages listed in requirements.txt using pip.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Run Combined Risk Analysis Script for Ticker AAPL
# Execute the command `python3 -m src.pipeline.run_combined_risk --ticker AAPL` using the integrated terminal or a subprocess call in Python.

# %%
# !python3 -m src.pipeline.run_combined_risk --ticker AAPL
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/workspaces/sec-red-flag-engine/src/pipeline/run_combined_risk.py", line 61, in <module>
#     main()
#   File "/workspaces/sec-red-flag-engine/src/pipeline/run_combined_risk.py", line 28, in main
#     raise FileNotFoundError(f"Missing required file: {path}")
# FileNotFoundError: Missing required file: /workspaces/sec-red-flag-engine/data/processed/aapl/zscore_yearly_summary.csv

# %% [markdown]
# # Display Script Output
# Capture and display the output from the risk analysis script execution in the notebook output cell.

# %% [markdown]
# # Full Data Pipeline for AAPL
#
# Run the complete pipeline: fetch data, build financials, EDA, and all analyses.

# %%
# !python3 -m src.pipeline.fetch_company_data --ticker AAPL
# Out:
# Resolved ticker AAPL -> CIK 0000320193 (Apple Inc.)
# Saved: /workspaces/sec-red-flag-engine/data/raw/aapl/submissions.json
# Saved: /workspaces/sec-red-flag-engine/data/raw/aapl/companyfacts.json
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/recent_filings.csv
#
# Recent filing form counts:
# form
# 4           591
# 8-K         105
# 424B2        50
# 144          40
# 10-Q         33
# PX14A6G      27
# FWP          25
# SC 13G/A     22
# DEFA14A      12
# 3            11
# DEF 14A      11
# 10-K         11
# SD           10
# NO ACT        7
# S-8           5
# Name: count, dtype: int64
#
# Recent annual filings:
# filingDate form      accessionNumber      primaryDocument primaryDocDescription
# 2025-10-31 10-K 0000320193-25-000079    aapl-20250927.htm                  10-K
# 2024-11-01 10-K 0000320193-24-000123    aapl-20240928.htm                  10-K
# 2023-11-03 10-K 0000320193-23-000106    aapl-20230930.htm                  10-K
# ...

# %%
# !python3 -m src.pipeline.build_annual_financials --ticker AAPL
# Out:
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/annual_facts_long.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/annual_financials.csv
#
# Annual facts preview:
#              metric                                 source_tag  tag_rank     kind   fy         val   form fp      filed        end      start duration_days frame                 accn
#                 cfo NetCashProvidedByUsedInOperatingActivities         1 duration 2009 10159000000 10-K/A FY 2010-01-25 2009-09-26 2008-09-28           363   NaN 0001193125-10-012091
#                cogs                 CostOfGoodsAndServicesSold         4 duration 2009 25683000000 10-K/A FY 2010-01-25 2009-09-26 2008-09-28           363   NaN 0001193125-10-012091
#      current_assets                              AssetsCurrent         1  instant 2009 31555000000 10-K/A FY 2010-01-25 2009-09-26        NaT          <NA>   NaN 0001193125-10-012091
# ...

# %%
# !python3 -m src.pipeline.run_annual_eda --ticker AAPL
# Out:
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/annual_financials_enriched.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/annual_missingness_report.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/annual_summary_stats.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/annual_anomaly_hints.csv
#
# Missingness report:
#                  column  missing_count  missing_pct
#            current_debt              6        35.29
#          long_term_debt              4        23.53
#                 ppe_yoy              4        23.53
#                     ppe              3        17.65
#                 cfo_yoy              1         5.88
#      current_assets_yoy              1         5.88
# current_liabilities_yoy              1         5.88
#        depreciation_yoy              1         5.88
#          net_income_yoy              1         5.88
#         receivables_yoy              1         5.88
# ...

# %%
# !python3 -m src.pipeline.run_zscore_analysis --ticker AAPL
# Out:
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/zscore_feature_selection.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/annual_financials_zscores.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/zscore_anomalies_long.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/zscore_yearly_summary.csv
#
# Selected features for Z-score:
#                 feature  exists  non_null_count  missing_pct      std  selected exclusion_reason
#          asset_turnover    True              17         0.00 0.155771      True
#       cfo_to_net_income    True              17         0.00 0.143274      True
#          cfo_to_revenue    True              17         0.00 0.028091      True
#                 cfo_yoy    True              16         5.88 0.318698      True
#      current_assets_yoy    True              16         5.88 0.142998      True
# current_liabilities_yoy    True              16         5.88 0.224730      True
# ...

# %%
# !python3 -m src.pipeline.run_beneish_analysis --ticker AAPL
# Out:
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/annual_beneish_features.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/beneish_summary.csv
#
# Beneish summary:
#  fiscal_year  beneish_input_count  beneish_complete  beneish_mscore  beneish_flag     beneish_label  gross_profit_used_fallback  cogs_used_fallback  total_debt_used_liabilities_proxy  tata_uses_net_income_proxy
#         2009                    1             False             NaN         False insufficient_data                       False               False                               True                        True
#         2010                    6             False             NaN         False insufficient_data                       False               False                               True                        True
# ...

# %%
# !python3 -m src.pipeline.run_isolation_forest_analysis --ticker AAPL
# Out:
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/iforest_feature_report.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/iforest_feature_matrix.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/annual_financials_iforest.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/iforest_anomalies_long.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/iforest_summary.csv
#
# Isolation Forest feature report:
#                 feature  exists  non_null_count  missing_pct      std  selected     exclusion_reason  missing_before  missing_after  median_used_for_imputation
#          asset_turnover    True              17         0.00 0.155771      True                                  0.0            0.0                    0.867550
#       cfo_to_net_income    True              17         0.00 0.143274      True                                  0.0            0.0                    1.300734
# ...

# %%
# !python3 -m src.pipeline.run_combined_risk --ticker AAPL
# Out:
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/combined_risk_summary.csv
# Saved: /workspaces/sec-red-flag-engine/data/processed/aapl/combined_risk_focus_years.csv
#
# Combined risk summary:
#  fiscal_year  zscore_available  zscore_triggered  zscore_anomaly_count  zscore_max_abs_zscore                                             zscore_features_triggered zscore_risk_level  beneish_available  beneish_triggered  beneish_input_count  beneish_mscore  beneish_flag     beneish_label  iforest_available  iforest_triggered  if_score_samples  if_decision_function  if_prediction  if_flag if_label  if_anomaly_strength_rank  available_method_count  triggered_method_count               triggered_methods         coverage_note combined_risk_level
# ...
